# %% [markdown]
# # Mouse Sleep Staging Validation dataset (MSSV)
#
# [dataset](https://openneuro.org/datasets/ds006366/versions/1.0.0) - _subject 1_ - __European Data Format (.edf)__  - mouse-sleep-staging-validation-dataset/sub-001_task-sleep_run-1_eeg

# %% [markdown]
# # illusory-face-eeg
#
# [dataset](https://openneuro.org/datasets/ds005642/versions/1.0.1) - _subject 1_ - __BioSemi data format (.bdf)__ - illusory-face-eeg/sub-01_task-faceobj_eeg.bdf

# %% [markdown]
# # Resting EEG
#
# [dataset](https://openneuro.org/datasets/ds005779/versions/1.0.1) - _Subject 1_ - __European Data Format (.edf)__ - resting-eeg/sub-001_task-resting_eeg.set
