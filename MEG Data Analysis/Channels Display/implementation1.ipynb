# %%
import matplotlib.pyplot as plt
import numpy as np
import mne

# %%
raw_file = mne.io.read_raw_fif(r"D:\.Important\Github Repositories\Neuroscience\MEG Data Analysis\MEGs Data\1\sub-01_ses-01_task-main_run-01_meg.fif")
# Out:
# Opening raw data file D:\.Important\Github Repositories\Neuroscience\MEG Data Analysis\MEGs Data\1\sub-01_ses-01_task-main_run-01_meg.fif...
#     Read a total of 6 projection items:
#         grad_ssp_upright2.fif : PCA-v1 (1 x 306)  idle
#         grad_ssp_upright2.fif : PCA-v2 (1 x 306)  idle
#         grad_ssp_upright2.fif : PCA-v3 (1 x 306)  idle
#         mag_ssp_upright2.fif : PCA-v1 (1 x 306)  idle
#         mag_ssp_upright2.fif : PCA-v2 (1 x 306)  idle
#         mag_ssp_upright2.fif : PCA-v3 (1 x 306)  idle
#     Range : 39000 ... 521999 =     39.000 ...   521.999 secs
# Ready.

# %%
raw_file.compute_psd(fmax=50).plot(picks="data", exclude="bads", amplitude=False)
# Out:
# Effective window size : 2.048 (s)
# Plotting power spectral density (dB=True).
# d:\Toolkit\Python\Lib\site-packages\mne\viz\utils.py:158: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   (fig or plt).show(**kwargs)
# <MNELineFigure size 1000x600 with 4 Axes>
